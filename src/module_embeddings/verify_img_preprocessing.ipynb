# %%
import sys
import os

# Añadir el directorio al sys.path
sys.path.append('/app/src/common')

# Importar el módulo utils
from utils import load_image, show_image # type: ignore
import matplotlib.pyplot as plt # type: ignore
import matplotlib.image as mpimg # type: ignore
import os

# Obtener la ruta absoluta del directorio actual en un Jupyter Notebook
current_dir = os.getcwd()

# Construir la ruta relativa a la imagen
image_path = os.path.join(current_dir, '/app/Imagenes_Panes/Image001.png')

# Cargar y mostrar la imagen
img = mpimg.imread(image_path)
show_image(img)

# %%
# Cargar y mostrar la imagen
try:
    image = load_image(image_path)
    show_image(image, "Imagen")
except FileNotFoundError:
    print(f"No se encontró la imagen en la ruta: {image_path}")
